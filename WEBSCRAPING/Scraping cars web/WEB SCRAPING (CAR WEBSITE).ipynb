# %% [markdown]
# #### Step 1 - Imports

# %%
import requests 
import pandas as pd

# %% [markdown]
# #### Step 2 - CURL

# %% [markdown]
# Copying the link from the website in curl(cmd)form and converting the curl for python

# %%
headers = {
    'authority': 'www.autolist.com',
    'sec-ch-ua': '^\\^Chromium^\\^;v=^\\^94^\\^, ^\\^Google',
    'accept': '*/*',
    'x-requested-with': 'XMLHttpRequest',
    'sec-ch-ua-mobile': '?0',
    'x-autolist-session-guid': 'c9fb9ffb-2c06-4468-a3d0-c26290c6994f',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/94.0.4590.0 Safari/537.36',
    'sec-ch-ua-platform': '^\\^Windows^\\^',
    'sec-fetch-site': 'same-origin',
    'sec-fetch-mode': 'cors',
    'sec-fetch-dest': 'empty',
    'referer': 'https://www.autolist.com/listings',
    'accept-language': 'en-US,en;q=0.9',
    'cookie': 'ec=eyJlZGdlVXNlckFnZW50IjoiTW96aWxsYS81LjAgKFdpbmRvd3MgTlQgMTAuMDsgV2luNjQ7IHg2NCkgQXBwbGVXZWJLaXQvNTM3LjM2IChLSFRNTCwgbGlrZSBHZWNrbykgQ2hyb21lLzk0LjAuNDU5MC4wIFNhZmFyaS81MzcuMzYifQ==; client_guid_timestamp=1602952f-d1bf-4936-82e3-cbdedfa11d2d.1627825394925; scavenger-a493=...; _sp_ses.8ca5=*; _gid=GA1.2.96049973.1627825395; _fbp=fb.1.1627825395573.409117512; __gads=ID=c459f8bf6d0987dd:T=1627825394:S=ALNI_MaW1epD3HNJsvJQTCnPWSJCcOdE_w; AMP_TOKEN=^%^24NOT_FOUND; sp-nuid=e4461948-a1a2-45a1-88f8-45c2889d9576; _gcl_au=1.1.519751617.1627825557; _ga_152345333=GS1.1.1627825395.1.1.1627828426.0; _ga=GA1.2.2118379867.1627825395; cto_bundle=WV1etl8zMUc1cGt6WnZNSEZMYWhwNnJjUXpTYzQxVzZ6QzM5VE1tWXZFcjQ3ZWhrNTlETG1CemlUdmNFYUtIbXdCQTNFelJmY3h6QXA0SlVIZml0WVg2OWQxZlBPMmRqbExXNU9XZTM0V0VaR09tbHBvJTJGdERCb21zZUVKJTJCTG1vVzlDV0w2VjA0bDklMkJnRjdrMmZPUExmJTJGY0l6USUzRCUzRA; _gat=1; _sp_id.8ca5=d3d3f60d-371c-4289-92fe-1c6f66b4979f.1627825395.1.1627828912.1627825395.8bc1e545-8ca1-448e-b1ba-ec8d2c359ada',
    'if-none-match': 'W/^\\^c6f72fa4ef059e03ea0309ebd57c197d^\\^',
}

params = (
    ('make', 'Tesla'),
    ('location', 'San^%^20Francisco,^%^20CA'),
    ('latitude', '37.7749295'),
    ('longitude', '-122.4194155'),
    ('radius', '50'),
    ('page', '1'),
)

response = requests.get('https://www.autolist.com/api/cwv/seo/listings', headers=headers, params=params)

# %% [markdown]
# #### Step 3 - Check Status Code

# %%
response
# Out:
# <Response [200]>

# %% [markdown]
# #### Step 4 - Create Json Object

# %%
response.json()
# Out:
# {'total_results_count': 1243,
#  'make_model_name': 'Tesla',
#  'trims': [],
#  'ad_info': {'ad_unit': '/19485787/AutoList.com/Search_Results_Page/Tesla',
#   'make': 'Tesla',
#   'model': None,
#   'page_type': 'srp',
#   'cpo': False,
#   'body_style': None,
#   'year': 2023,
#   'age_type': 'new',
#   'app': 'web',
#   'seller_id': None,
#   'content_url': 'https://www.autolist.com/listings#latitude=37.7749295&location=San%5E%25%5E20Francisco%2C%5E%25%5E20CA&longitude=-122.4194155&make=Tesla&page=1&radius=50'},
#  'search_results': [{'available_nationwide': False,
#    'created_at': 1637600594,
#    'recent_price_drop': False,
#    'is_hot': False,
#    'href_target': '/listings/5YJ3E1EB4JF094546',
#    'vdp_url': '/tesla-model+3#vin=5YJ3E1EB4JF094546',
#    'clickoff_url': 'https://www.shift.com/car/c191146?utm_source=Autolist&utm_medium=listing&utm_campaign=deeplink',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 232010619,
#    'primary_photo_url': 'https://static.cargurus.com/images/forsale/2021/12/08/18/14/2018_tesla_model_3-pic-3933473144524356802-1024x768.jpeg',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--dPaVpWMF--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2021/12/08/18/14/2018_tesla_model_3-pic-3933473144524356802-1024x768.jpeg',
#    'lat': 37.6442,
#    'lon': -122.398,
#    'year': 2018,
#    'make': 'Tesla',
#    'model': 'Model 3',
#    'model_id': 2217,
#    'display_color': '',
#    'price': '$45,950',
#    'price_unformatted': 45950,
#    'mileage': '35,226 Miles',
#    'mileage_unformatted': 35226,
#    'city': 'South San Francisco',
#    'state': 'CA',
#    'distance_from_origin': 9,
#    'dealer_name': 'Shift SF - Test Drives Delivered To You',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '5YJ3E1EB4JF094546',
#    'provider': None,
#    'provider_name': 'car_gurus',
#    'always_ask_for_zip': False,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '317475865',
#     'remote_dealer_id': '413397',
#     'dealer_name': 'Shift SF - Test Drives Delivered to You',
#     'remote_sku': 'c191146',
#     'experience': 'regional',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'shift_sf_test_drives_deliveredto_you_two',
#     'dealer_uuid': 'a13d929d-f3f8-417c-9417-128dbb8ab28b',
#     'dealer_group_unique_name': 'shift_cargurus',
#     'dealer_group_uuid': '88c7994e-2ed1-4892-b70f-55ba4c3e5540'},
#    'trim': 'Long Range',
#    'provider_id': 199,
#    'provider_group_id': 231,
#    'experience': 'regional',
#    'regional': True,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1640793845,
#    'recent_price_drop': False,
#    'is_hot': False,
#    'href_target': '/listings/5YJ3E1EB4LF650017',
#    'vdp_url': '/tesla-model+3#vin=5YJ3E1EB4LF650017',
#    'clickoff_url': 'https://www.shift.com/car/c1403290?utm_source=Autolist&utm_medium=listing&utm_campaign=deeplink',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 234321716,
#    'primary_photo_url': 'https://static.cargurus.com/images/forsale/2021/12/31/08/46/2020_tesla_model_3-pic-8934864150452044949-1024x768.jpeg',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--qOc0JqDA--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2021/12/31/08/46/2020_tesla_model_3-pic-8934864150452044949-1024x768.jpeg',
#    'lat': 37.6397,
#    'lon': -122.416,
#    'year': 2020,
#    'make': 'Tesla',
#    'model': 'Model 3',
#    'model_id': 2217,
#    'display_color': '',
#    'price': '$52,850',
#    'price_unformatted': 52850,
#    'mileage': '10,640 Miles',
#    'mileage_unformatted': 10640,
#    'city': 'South San Francisco',
#    'state': 'CA',
#    'distance_from_origin': 9,
#    'dealer_name': 'Shift SF - Test Drives Delivered To You',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '5YJ3E1EB4LF650017',
#    'provider': None,
#    'provider_name': 'car_gurus',
#    'always_ask_for_zip': False,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '320112155',
#     'remote_dealer_id': '413397',
#     'dealer_name': 'Shift SF - Test Drives Delivered to You',
#     'remote_sku': 'c1403290',
#     'experience': 'regional',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'shift_sf_test_drives_deliveredto_you_two',
#     'dealer_uuid': 'a13d929d-f3f8-417c-9417-128dbb8ab28b',
#     'dealer_group_unique_name': 'shift_cargurus',
#     'dealer_group_uuid': '88c7994e-2ed1-4892-b70f-55ba4c3e5540'},
#    'trim': 'Long Range',
#    'provider_id': 199,
#    'provider_group_id': 231,
#    'experience': 'regional',
#    'regional': True,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1642471644,
#    'recent_price_drop': False,
#    'is_hot': False,
#    'href_target': '/listings/5YJ3E1EA9JF020658',
#    'vdp_url': '/tesla-model+3#vin=5YJ3E1EA9JF020658',
#    'clickoff_url': 'https://www.shift.com/car/c1855332?utm_source=Autolist&utm_medium=listing&utm_campaign=deeplink',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 235497388,
#    'primary_photo_url': 'https://static.cargurus.com/images/forsale/2022/01/17/17/17/2018_tesla_model_3-pic-1369659021280440554-1024x768.jpeg',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--rACAcEY5--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2022/01/17/17/17/2018_tesla_model_3-pic-1369659021280440554-1024x768.jpeg',
#    'lat': 37.6397,
#    'lon': -122.416,
#    'year': 2018,
#    'make': 'Tesla',
#    'model': 'Model 3',
#    'model_id': 2217,
#    'display_color': '',
#    'price': '$43,950',
#    'price_unformatted': 43950,
#    'mileage': '53,129 Miles',
#    'mileage_unformatted': 53129,
#    'city': 'South San Francisco',
#    'state': 'CA',
#    'distance_from_origin': 9,
#    'dealer_name': 'Shift SF - Test Drives Delivered To You',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '5YJ3E1EA9JF020658',
#    'provider': None,
#    'provider_name': 'car_gurus',
#    'always_ask_for_zip': False,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '321403247',
#     'remote_dealer_id': '413397',
#     'dealer_name': 'Shift SF - Test Drives Delivered to You',
#     'remote_sku': 'c1855332',
#     'experience': 'regional',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'shift_sf_test_drives_deliveredto_you_two',
#     'dealer_uuid': 'a13d929d-f3f8-417c-9417-128dbb8ab28b',
#     'dealer_group_unique_name': 'shift_cargurus',
#     'dealer_group_uuid': '88c7994e-2ed1-4892-b70f-55ba4c3e5540'},
#    'trim': 'Standard',
#    'provider_id': 199,
#    'provider_group_id': 231,
#    'experience': 'regional',
#    'regional': True,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1641965644,
#    'recent_price_drop': False,
#    'is_hot': False,
#    'href_target': '/listings/5YJ3E1EAXKF422724',
#    'vdp_url': '/tesla-model+3#vin=5YJ3E1EAXKF422724',
#    'clickoff_url': 'https://www.carmax.com/car/21241865?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 235114535,
#    'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21241865/1.jpg?width=1024&watermark=LYCG_1a',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--Wb_b9UT_--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21241865/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#    'lat': 37.69056829597337,
#    'lon': -122.4466776578749,
#    'year': 2019,
#    'make': 'Tesla',
#    'model': 'Model 3',
#    'model_id': 2217,
#    'display_color': '',
#    'price': '$42,998',
#    'price_unformatted': 42998,
#    'mileage': '41,210 Miles',
#    'mileage_unformatted': 41210,
#    'city': 'Colma',
#    'state': 'CA',
#    'distance_from_origin': 6,
#    'dealer_name': 'CarMax Serramonte - Now Open',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '5YJ3E1EAXKF422724',
#    'provider': None,
#    'provider_name': 'carmax',
#    'always_ask_for_zip': True,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '5YJ3E1EAXKF422724',
#     'remote_dealer_id': '6080',
#     'dealer_name': 'CarMax Serramonte',
#     'remote_sku': '21241865',
#     'experience': 'local',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'carmax_serramonte',
#     'dealer_uuid': '2bf4fe81-333d-498d-8994-1b7e0d050334',
#     'dealer_group_unique_name': 'carmax',
#     'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#    'trim': 'Standard Range Plus',
#    'provider_id': 146,
#    'provider_group_id': 149,
#    'experience': 'local_if_nearby',
#    'regional': False,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1642176600,
#    'recent_price_drop': False,
#    'is_hot': False,
#    'href_target': '/listings/5YJ3E1EB9KF511760',
#    'vdp_url': '/tesla-model+3#vin=5YJ3E1EB9KF511760',
#    'clickoff_url': 'https://www.shift.com/car/c1272784?utm_source=Autolist&utm_medium=listing&utm_campaign=deeplink',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 235304456,
#    'primary_photo_url': 'https://static.cargurus.com/images/forsale/2022/01/14/09/03/2019_tesla_model_3-pic-3323151348962915799-1024x768.jpeg',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--oTYPhn6J--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2022/01/14/09/03/2019_tesla_model_3-pic-3323151348962915799-1024x768.jpeg',
#    'lat': 37.6397,
#    'lon': -122.416,
#    'year': 2019,
#    'make': 'Tesla',
#    'model': 'Model 3',
#    'model_id': 2217,
#    'display_color': '',
#    'price': '$49,950',
#    'price_unformatted': 49950,
#    'mileage': '28,890 Miles',
#    'mileage_unformatted': 28890,
#    'city': 'South San Francisco',
#    'state': 'CA',
#    'distance_from_origin': 9,
#    'dealer_name': 'Shift SF - Test Drives Delivered To You',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '5YJ3E1EB9KF511760',
#    'provider': None,
#    'provider_name': 'car_gurus',
#    'always_ask_for_zip': False,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '321203974',
#     'remote_dealer_id': '413397',
#     'dealer_name': 'Shift SF - Test Drives Delivered to You',
#     'remote_sku': 'c1272784',
#     'experience': 'regional',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'shift_sf_test_drives_deliveredto_you_two',
#     'dealer_uuid': 'a13d929d-f3f8-417c-9417-128dbb8ab28b',
#     'dealer_group_unique_name': 'shift_cargurus',
#     'dealer_group_uuid': '88c7994e-2ed1-4892-b70f-55ba4c3e5540'},
#    'trim': 'Long Range',
#    'provider_id': 199,
#    'provider_group_id': 231,
#    'experience': 'regional',
#    'regional': True,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1638941981,
#    'recent_price_drop': False,
#    'is_hot': False,
#    'href_target': '/listings/5YJ3E1EB6LF651119',
#    'vdp_url': '/tesla-model+3#vin=5YJ3E1EB6LF651119',
#    'clickoff_url': 'https://www.carmax.com/car/21359622?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 232992701,
#    'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21359622/1.jpg?width=1024&watermark=LYCG_1a',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--UG2UyTC5--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21359622/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#    'lat': 38.27872113250454,
#    'lon': -122.0043812304184,
#    'year': 2020,
#    'make': 'Tesla',
#    'model': 'Model 3',
#    'model_id': 2217,
#    'display_color': '',
#    'price': '$56,998',
#    'price_unformatted': 56998,
#    'mileage': '11,643 Miles',
#    'mileage_unformatted': 11643,
#    'city': 'Fairfield',
#    'state': 'CA',
#    'distance_from_origin': 41,
#    'dealer_name': 'CarMax Fairfield - Now Offering Curbside Pickup And Home Delivery',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '5YJ3E1EB6LF651119',
#    'provider': None,
#    'provider_name': 'carmax',
#    'always_ask_for_zip': True,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '5YJ3E1EB6LF651119',
#     'remote_dealer_id': '6048',
#     'dealer_name': 'CarMax Fairfield',
#     'remote_sku': '21359622',
#     'experience': 'local',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'carmax_fairfield',
#     'dealer_uuid': '129aa2eb-3d7a-430c-a516-e65841530372',
#     'dealer_group_unique_name': 'carmax',
#     'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#    'trim': 'Long Range',
#    'provider_id': 146,
#    'provider_group_id': 149,
#    'experience': 'local',
#    'regional': False,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1641347716,
#    'recent_price_drop': False,
#    'is_hot': False,
#    'href_target': '/listings/5YJ3E1EBXLF650345',
#    'vdp_url': '/tesla-model+3#vin=5YJ3E1EBXLF650345',
#    'clickoff_url': 'https://www.shift.com/car/c162764?utm_source=Autolist&utm_medium=listing&utm_campaign=deeplink',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 234690633,
#    'primary_photo_url': 'https://static.cargurus.com/images/forsale/2022/01/04/08/56/2020_tesla_model_3-pic-7884639301210219313-1024x768.jpeg',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--qC5jlZO4--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2022/01/04/08/56/2020_tesla_model_3-pic-7884639301210219313-1024x768.jpeg',
#    'lat': 37.6397,
#    'lon': -122.416,
#    'year': 2020,
#    'make': 'Tesla',
#    'model': 'Model 3',
#    'model_id': 2217,
#    'display_color': '',
#    'price': '$52,950',
#    'price_unformatted': 52950,
#    'mileage': '5,616 Miles',
#    'mileage_unformatted': 5616,
#    'city': 'South San Francisco',
#    'state': 'CA',
#    'distance_from_origin': 9,
#    'dealer_name': 'Shift SF - Test Drives Delivered To You',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '5YJ3E1EBXLF650345',
#    'provider': None,
#    'provider_name': 'car_gurus',
#    'always_ask_for_zip': False,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '320503319',
#     'remote_dealer_id': '413397',
#     'dealer_name': 'Shift SF - Test Drives Delivered to You',
#     'remote_sku': 'c162764',
#     'experience': 'regional',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'shift_sf_test_drives_deliveredto_you_two',
#     'dealer_uuid': 'a13d929d-f3f8-417c-9417-128dbb8ab28b',
#     'dealer_group_unique_name': 'shift_cargurus',
#     'dealer_group_uuid': '88c7994e-2ed1-4892-b70f-55ba4c3e5540'},
#    'trim': 'Long Range',
#    'provider_id': 199,
#    'provider_group_id': 231,
#    'experience': 'regional',
#    'regional': True,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1640224618,
#    'recent_price_drop': False,
#    'is_hot': False,
#    'href_target': '/listings/5YJSA1H11EFP34339',
#    'vdp_url': '/tesla-model+s#vin=5YJSA1H11EFP34339',
#    'clickoff_url': 'https://www.shift.com/car/c1623754?utm_source=Autolist&utm_medium=listing&utm_campaign=deeplink',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 233976733,
#    'primary_photo_url': 'https://static.cargurus.com/images/forsale/2021/12/23/09/01/2014_tesla_model_s-pic-2455421630007525675-1024x768.jpeg',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--4O4EE2NI--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2021/12/23/09/01/2014_tesla_model_s-pic-2455421630007525675-1024x768.jpeg',
#    'lat': 37.6397,
#    'lon': -122.416,
#    'year': 2014,
#    'make': 'Tesla',
#    'model': 'Model S',
#    'model_id': 2006,
#    'display_color': '',
#    'price': '$37,950',
#    'price_unformatted': 37950,
#    'mileage': '59,599 Miles',
#    'mileage_unformatted': 59599,
#    'city': 'South San Francisco',
#    'state': 'CA',
#    'distance_from_origin': 9,
#    'dealer_name': 'Shift SF - Test Drives Delivered To You',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '5YJSA1H11EFP34339',
#    'provider': None,
#    'provider_name': 'car_gurus',
#    'always_ask_for_zip': False,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '319725788',
#     'remote_dealer_id': '413397',
#     'dealer_name': 'Shift SF - Test Drives Delivered to You',
#     'remote_sku': 'c1623754',
#     'experience': 'regional',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'shift_sf_test_drives_deliveredto_you_two',
#     'dealer_uuid': 'a13d929d-f3f8-417c-9417-128dbb8ab28b',
#     'dealer_group_unique_name': 'shift_cargurus',
#     'dealer_group_uuid': '88c7994e-2ed1-4892-b70f-55ba4c3e5540'},
#    'trim': '85',
#    'provider_id': 199,
#    'provider_group_id': 231,
#    'experience': 'regional',
#    'regional': True,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1641965644,
#    'recent_price_drop': False,
#    'is_hot': False,
#    'href_target': '/listings/5YJ3E1EA6JF158397',
#    'vdp_url': '/tesla-model+3#vin=5YJ3E1EA6JF158397',
#    'clickoff_url': 'https://www.carmax.com/car/21623844?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 235114530,
#    'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21623844/1.jpg?width=1024&watermark=LYCG_1a',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--B7P3SEmd--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21623844/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#    'lat': 37.69056829597337,
#    'lon': -122.4466776578749,
#    'year': 2018,
#    'make': 'Tesla',
#    'model': 'Model 3',
#    'model_id': 2217,
#    'display_color': '',
#    'price': '$44,998',
#    'price_unformatted': 44998,
#    'mileage': '31,518 Miles',
#    'mileage_unformatted': 31518,
#    'city': 'Colma',
#    'state': 'CA',
#    'distance_from_origin': 6,
#    'dealer_name': 'CarMax Serramonte - Now Open',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '5YJ3E1EA6JF158397',
#    'provider': None,
#    'provider_name': 'carmax',
#    'always_ask_for_zip': True,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '5YJ3E1EA6JF158397',
#     'remote_dealer_id': '6080',
#     'dealer_name': 'CarMax Serramonte',
#     'remote_sku': '21623844',
#     'experience': 'local',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'carmax_serramonte',
#     'dealer_uuid': '2bf4fe81-333d-498d-8994-1b7e0d050334',
#     'dealer_group_unique_name': 'carmax',
#     'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#    'trim': 'Standard',
#    'provider_id': 146,
#    'provider_group_id': 149,
#    'experience': 'local_if_nearby',
#    'regional': False,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1642817179,
#    'recent_price_drop': None,
#    'is_hot': False,
#    'href_target': '/listings/5YJ3E1EA6JF053892',
#    'vdp_url': '/tesla-model+3#vin=5YJ3E1EA6JF053892',
#    'clickoff_url': 'https://www.shift.com/car/c195777?utm_source=Autolist&utm_medium=listing&utm_campaign=deeplink',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 235784316,
#    'primary_photo_url': 'https://static.cargurus.com/images/forsale/2022/01/21/22/11/2018_tesla_model_3-pic-6819678569073037080-1024x768.jpeg',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--gBShw_4S--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2022/01/21/22/11/2018_tesla_model_3-pic-6819678569073037080-1024x768.jpeg',
#    'lat': 37.6397,
#    'lon': -122.416,
#    'year': 2018,
#    'make': 'Tesla',
#    'model': 'Model 3',
#    'model_id': 2217,
#    'display_color': '',
#    'price': '$42,950',
#    'price_unformatted': 42950,
#    'mileage': '56,823 Miles',
#    'mileage_unformatted': 56823,
#    'city': 'South San Francisco',
#    'state': 'CA',
#    'distance_from_origin': 9,
#    'dealer_name': 'Shift SF - Test Drives Delivered To You',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '5YJ3E1EA6JF053892',
#    'provider': None,
#    'provider_name': 'car_gurus',
#    'always_ask_for_zip': False,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '321729854',
#     'remote_dealer_id': '413397',
#     'dealer_name': 'Shift SF - Test Drives Delivered to You',
#     'remote_sku': 'c195777',
#     'experience': 'regional',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'shift_sf_test_drives_deliveredto_you_two',
#     'dealer_uuid': 'a13d929d-f3f8-417c-9417-128dbb8ab28b',
#     'dealer_group_unique_name': 'shift_cargurus',
#     'dealer_group_uuid': '88c7994e-2ed1-4892-b70f-55ba4c3e5540'},
#    'trim': 'Standard',
#    'provider_id': 199,
#    'provider_group_id': 231,
#    'experience': 'regional',
#    'regional': True,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1642009757,
#    'recent_price_drop': False,
#    'is_hot': False,
#    'href_target': '/listings/5YJ3E1EA8JF061217',
#    'vdp_url': '/tesla-model+3#vin=5YJ3E1EA8JF061217',
#    'clickoff_url': 'https://www.berkshirehathawayautomotive.com/catcher.esl?vin=5YJ3E1EA8JF061217&atc_ownerid=autolist&utm_source=autolist&utm_medium=referral&utm_campaign=vdp_deep_link',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 235154879,
#    'primary_photo_url': 'https://static.cargurus.com/images/forsale/2022/01/13/07/34/2018_tesla_model_3-pic-1708959278347123645-1024x768.jpeg',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--geKhe1mO--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2022/01/13/07/34/2018_tesla_model_3-pic-1708959278347123645-1024x768.jpeg',
#    'lat': 37.6732,
#    'lon': -122.463,
#    'year': 2018,
#    'make': 'Tesla',
#    'model': 'Model 3',
#    'model_id': 2217,
#    'display_color': '',
#    'price': '$47,991',
#    'price_unformatted': 47991,
#    'mileage': '17,885 Miles',
#    'mileage_unformatted': 17885,
#    'city': 'Colma',
#    'state': 'CA',
#    'distance_from_origin': 7,
#    'dealer_name': 'Serramonte Ford',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '5YJ3E1EA8JF061217',
#    'provider': None,
#    'provider_name': 'car_gurus',
#    'always_ask_for_zip': False,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '321025677',
#     'remote_dealer_id': '55246',
#     'dealer_name': 'Serramonte Ford',
#     'remote_sku': 'P4646',
#     'experience': 'local',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'serramonte_ford',
#     'dealer_uuid': 'c89730bc-a118-49cb-a50b-09c4ad611540',
#     'dealer_group_unique_name': 'berkshire_hathaway_automotive_car_gurus',
#     'dealer_group_uuid': '6edd5326-1c9f-408d-918f-8cb1cd0e2f01'},
#    'trim': 'Long Range',
#    'provider_id': 199,
#    'provider_group_id': 229,
#    'experience': 'local',
#    'regional': False,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1641015253,
#    'recent_price_drop': True,
#    'is_hot': False,
#    'href_target': '/listings/5YJ3E1EA2KF301508',
#    'vdp_url': '/tesla-model+3#vin=5YJ3E1EA2KF301508',
#    'clickoff_url': 'https://www.carmax.com/car/21915924?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 234532173,
#    'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21915924/1.jpg?width=1024&watermark=LYCG_1a',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--0xlfPyHw--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21915924/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#    'lat': 37.69056829597337,
#    'lon': -122.4466776578749,
#    'year': 2019,
#    'make': 'Tesla',
#    'model': 'Model 3',
#    'model_id': 2217,
#    'display_color': '',
#    'price': '$45,998',
#    'price_unformatted': 45998,
#    'mileage': '25,139 Miles',
#    'mileage_unformatted': 25139,
#    'city': 'Colma',
#    'state': 'CA',
#    'distance_from_origin': 6,
#    'dealer_name': 'CarMax Serramonte - Now Open',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '5YJ3E1EA2KF301508',
#    'provider': None,
#    'provider_name': 'carmax',
#    'always_ask_for_zip': True,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '5YJ3E1EA2KF301508',
#     'remote_dealer_id': '6080',
#     'dealer_name': 'CarMax Serramonte',
#     'remote_sku': '21915924',
#     'experience': 'local',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'carmax_serramonte',
#     'dealer_uuid': '2bf4fe81-333d-498d-8994-1b7e0d050334',
#     'dealer_group_unique_name': 'carmax',
#     'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#    'trim': 'Standard Range Plus',
#    'provider_id': 146,
#    'provider_group_id': 149,
#    'experience': 'local_if_nearby',
#    'regional': False,
#    'badges': {'position0': None, 'position1': 'price_drop'},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1635959165,
#    'recent_price_drop': True,
#    'is_hot': False,
#    'href_target': '/listings/5YJ3E1EA6JF010623',
#    'vdp_url': '/tesla-model+3#vin=5YJ3E1EA6JF010623',
#    'clickoff_url': 'https://www.lithia.com/catcher.esl?vin=5YJ3E1EA6JF010623&utm_source=autolist&utm_medium=referral&utm_campaign=vdp_deep_link',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 230794948,
#    'primary_photo_url': 'https://static.cargurus.com/images/forsale/2021/12/18/00/42/2018_tesla_model_3-pic-7240699439564966012-1024x768.jpeg',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--KN7Xnkd---/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2021/12/18/00/42/2018_tesla_model_3-pic-7240699439564966012-1024x768.jpeg',
#    'lat': 38.4108,
#    'lon': -122.719,
#    'year': 2018,
#    'make': 'Tesla',
#    'model': 'Model 3',
#    'model_id': 2217,
#    'display_color': '',
#    'price': '$45,997',
#    'price_unformatted': 45997,
#    'mileage': '35,118 Miles',
#    'mileage_unformatted': 35118,
#    'city': 'Santa Rosa',
#    'state': 'CA',
#    'distance_from_origin': 46,
#    'dealer_name': 'Lithia Chrysler Jeep Dodge Of Santa Rosa',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '5YJ3E1EA6JF010623',
#    'provider': None,
#    'provider_name': 'car_gurus',
#    'always_ask_for_zip': False,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '316091162',
#     'remote_dealer_id': '60398',
#     'dealer_name': 'Lithia Chrysler Jeep Dodge of Santa Rosa',
#     'remote_sku': 'JF010623',
#     'experience': 'local',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'lithia_chrysler_jeep_dodgeof_santa_rosa',
#     'dealer_uuid': '854da0e9-8c99-480f-a288-6a3905318ae0',
#     'dealer_group_unique_name': 'lithia_cargurus',
#     'dealer_group_uuid': 'c0fa20c8-42ae-44e3-a134-36b48b15907a'},
#    'trim': 'Long Range',
#    'provider_id': 199,
#    'provider_group_id': 229,
#    'experience': 'local',
#    'regional': False,
#    'badges': {'position0': None, 'position1': 'price_drop'},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1642817179,
#    'recent_price_drop': None,
#    'is_hot': False,
#    'href_target': '/listings/5YJSA1DPXDFP13482',
#    'vdp_url': '/tesla-model+s#vin=5YJSA1DPXDFP13482',
#    'clickoff_url': 'https://www.shift.com/car/c195818?utm_source=Autolist&utm_medium=listing&utm_campaign=deeplink',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 235784317,
#    'primary_photo_url': 'https://static.cargurus.com/images/forsale/2022/01/21/22/11/2013_tesla_model_s-pic-407864244813224049-1024x768.jpeg',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--ybyOZd4v--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2022/01/21/22/11/2013_tesla_model_s-pic-407864244813224049-1024x768.jpeg',
#    'lat': 37.6397,
#    'lon': -122.416,
#    'year': 2013,
#    'make': 'Tesla',
#    'model': 'Model S',
#    'model_id': 2006,
#    'display_color': '',
#    'price': '$33,950',
#    'price_unformatted': 33950,
#    'mileage': '103,479 Miles',
#    'mileage_unformatted': 103479,
#    'city': 'South San Francisco',
#    'state': 'CA',
#    'distance_from_origin': 9,
#    'dealer_name': 'Shift SF - Test Drives Delivered To You',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '5YJSA1DPXDFP13482',
#    'provider': None,
#    'provider_name': 'car_gurus',
#    'always_ask_for_zip': False,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '321729847',
#     'remote_dealer_id': '413397',
#     'dealer_name': 'Shift SF - Test Drives Delivered to You',
#     'remote_sku': 'c195818',
#     'experience': 'regional',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'shift_sf_test_drives_deliveredto_you_two',
#     'dealer_uuid': 'a13d929d-f3f8-417c-9417-128dbb8ab28b',
#     'dealer_group_unique_name': 'shift_cargurus',
#     'dealer_group_uuid': '88c7994e-2ed1-4892-b70f-55ba4c3e5540'},
#    'trim': 'Performance',
#    'provider_id': 199,
#    'provider_group_id': 231,
#    'experience': 'regional',
#    'regional': True,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1641571803,
#    'recent_price_drop': False,
#    'is_hot': False,
#    'href_target': '/listings/5YJ3E1EAXMF047033',
#    'vdp_url': '/tesla-model+3#vin=5YJ3E1EAXMF047033',
#    'clickoff_url': 'https://www.shift.com/car/c1835273?utm_source=Autolist&utm_medium=listing&utm_campaign=deeplink',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 234854528,
#    'primary_photo_url': 'https://static.cargurus.com/images/forsale/2022/01/07/08/55/2021_tesla_model_3-pic-1230773519567103780-1024x768.jpeg',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--UaosDYHY--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2022/01/07/08/55/2021_tesla_model_3-pic-1230773519567103780-1024x768.jpeg',
#    'lat': 37.6397,
#    'lon': -122.416,
#    'year': 2021,
#    'make': 'Tesla',
#    'model': 'Model 3',
#    'model_id': 2217,
#    'display_color': '',
#    'price': '$49,950',
#    'price_unformatted': 49950,
#    'mileage': '1,033 Miles',
#    'mileage_unformatted': 1033,
#    'city': 'South San Francisco',
#    'state': 'CA',
#    'distance_from_origin': 9,
#    'dealer_name': 'Shift SF - Test Drives Delivered To You',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '5YJ3E1EAXMF047033',
#    'provider': None,
#    'provider_name': 'car_gurus',
#    'always_ask_for_zip': False,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '320687138',
#     'remote_dealer_id': '413397',
#     'dealer_name': 'Shift SF - Test Drives Delivered to You',
#     'remote_sku': 'c1835273',
#     'experience': 'regional',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'shift_sf_test_drives_deliveredto_you_two',
#     'dealer_uuid': 'a13d929d-f3f8-417c-9417-128dbb8ab28b',
#     'dealer_group_unique_name': 'shift_cargurus',
#     'dealer_group_uuid': '88c7994e-2ed1-4892-b70f-55ba4c3e5540'},
#    'trim': 'Standard Range Plus',
#    'provider_id': 199,
#    'provider_group_id': 231,
#    'experience': 'regional',
#    'regional': True,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1641916892,
#    'recent_price_drop': False,
#    'is_hot': False,
#    'href_target': '/listings/5YJYGDEEXMF187815',
#    'vdp_url': '/tesla-model+y#vin=5YJYGDEEXMF187815',
#    'clickoff_url': 'https://www.shift.com/car/c111679?utm_source=Autolist&utm_medium=listing&utm_campaign=deeplink',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 235053010,
#    'primary_photo_url': 'https://static.cargurus.com/images/forsale/2022/01/11/02/19/2021_tesla_model_y-pic-6295954287222497048-1024x768.jpeg',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--3C_fKSnv--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2022/01/11/02/19/2021_tesla_model_y-pic-6295954287222497048-1024x768.jpeg',
#    'lat': 37.6397,
#    'lon': -122.416,
#    'year': 2021,
#    'make': 'Tesla',
#    'model': 'Model Y',
#    'model_id': 2357,
#    'display_color': '',
#    'price': '$64,950',
#    'price_unformatted': 64950,
#    'mileage': '8,849 Miles',
#    'mileage_unformatted': 8849,
#    'city': 'South San Francisco',
#    'state': 'CA',
#    'distance_from_origin': 9,
#    'dealer_name': 'Shift SF - Test Drives Delivered To You',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '5YJYGDEEXMF187815',
#    'provider': None,
#    'provider_name': 'car_gurus',
#    'always_ask_for_zip': False,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '320932984',
#     'remote_dealer_id': '413397',
#     'dealer_name': 'Shift SF - Test Drives Delivered to You',
#     'remote_sku': 'c111679',
#     'experience': 'regional',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'shift_sf_test_drives_deliveredto_you_two',
#     'dealer_uuid': 'a13d929d-f3f8-417c-9417-128dbb8ab28b',
#     'dealer_group_unique_name': 'shift_cargurus',
#     'dealer_group_uuid': '88c7994e-2ed1-4892-b70f-55ba4c3e5540'},
#    'trim': 'Long Range',
#    'provider_id': 199,
#    'provider_group_id': 231,
#    'experience': 'regional',
#    'regional': True,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1641793133,
#    'recent_price_drop': True,
#    'is_hot': False,
#    'href_target': '/listings/5YJ3E1EA2MF051643',
#    'vdp_url': '/tesla-model+3#vin=5YJ3E1EA2MF051643',
#    'clickoff_url': 'https://www.carmax.com/car/21669917?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 235018705,
#    'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21669917/1.jpg?width=1024&watermark=LYCG_1a',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--QVDOQTsn--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21669917/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#    'lat': 38.241385,
#    'lon': -122.083855,
#    'year': 2021,
#    'make': 'Tesla',
#    'model': 'Model 3',
#    'model_id': 2217,
#    'display_color': '',
#    'price': '$50,998',
#    'price_unformatted': 50998,
#    'mileage': '2,134 Miles',
#    'mileage_unformatted': 2134,
#    'city': 'Fairfield',
#    'state': 'CA',
#    'distance_from_origin': 37,
#    'dealer_name': 'CarMax Fairfield - Now Offering Curbside Pickup And Home Delivery',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '5YJ3E1EA2MF051643',
#    'provider': None,
#    'provider_name': 'carmax',
#    'always_ask_for_zip': True,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '5YJ3E1EA2MF051643',
#     'remote_dealer_id': '6048',
#     'dealer_name': 'CarMax Fairfield',
#     'remote_sku': '21669917',
#     'experience': 'local',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'carmax_fairfield',
#     'dealer_uuid': '129aa2eb-3d7a-430c-a516-e65841530372',
#     'dealer_group_unique_name': 'carmax',
#     'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#    'trim': 'Standard Range Plus',
#    'provider_id': 146,
#    'provider_group_id': 149,
#    'experience': 'local',
#    'regional': False,
#    'badges': {'position0': None, 'position1': 'price_drop'},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1639844479,
#    'recent_price_drop': False,
#    'is_hot': False,
#    'href_target': '/listings/5YJSA1H29EFP62821',
#    'vdp_url': '/tesla-model+s#vin=5YJSA1H29EFP62821',
#    'clickoff_url': '',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 233683428,
#    'primary_photo_url': 'https://static.cargurus.com/images/forsale/2021/12/18/00/14/2014_tesla_model_s-pic-567426342306914240-1024x768.jpeg',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--JNfWK4I0--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2021/12/18/00/14/2014_tesla_model_s-pic-567426342306914240-1024x768.jpeg',
#    'lat': 37.9628,
#    'lon': -122.51,
#    'year': 2014,
#    'make': 'Tesla',
#    'model': 'Model S',
#    'model_id': 2006,
#    'display_color': '',
#    'price': '$56,988',
#    'price_unformatted': 56988,
#    'mileage': '39,281 Miles',
#    'mileage_unformatted': 39281,
#    'city': 'San Rafael',
#    'state': 'CA',
#    'distance_from_origin': 13,
#    'dealer_name': 'Marin Mazda',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 3,
#    'partner_type': 'metasearch',
#    'vin': '5YJSA1H29EFP62821',
#    'provider': None,
#    'provider_name': 'car_gurus',
#    'always_ask_for_zip': False,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '319408507',
#     'remote_dealer_id': '285232',
#     'dealer_name': None,
#     'remote_sku': '15930',
#     'experience': 'local',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': None,
#     'dealer_uuid': None,
#     'dealer_group_unique_name': None,
#     'dealer_group_uuid': None},
#    'trim': 'P85D',
#    'provider_id': 199,
#    'provider_group_id': 227,
#    'experience': 'local',
#    'regional': False,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': True},
#   {'available_nationwide': False,
#    'created_at': 1642903393,
#    'recent_price_drop': None,
#    'is_hot': False,
#    'href_target': '/listings/5YJSA1E29JF250636',
#    'vdp_url': '/tesla-model+s#vin=5YJSA1E29JF250636',
#    'clickoff_url': 'https://www.shift.com/car/c1011419?utm_source=Autolist&utm_medium=listing&utm_campaign=deeplink',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 235868340,
#    'primary_photo_url': 'https://static.cargurus.com/images/forsale/2020/02/06/16/28/2018_tesla_model_s-pic-2835982302413402780-1024x768.jpeg',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--9wflisjW--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2020/02/06/16/28/2018_tesla_model_s-pic-2835982302413402780-1024x768.jpeg',
#    'lat': 37.6397,
#    'lon': -122.416,
#    'year': 2018,
#    'make': 'Tesla',
#    'model': 'Model S',
#    'model_id': 2006,
#    'display_color': '',
#    'price': '$61,950',
#    'price_unformatted': 61950,
#    'mileage': '51,550 Miles',
#    'mileage_unformatted': 51550,
#    'city': 'South San Francisco',
#    'state': 'CA',
#    'distance_from_origin': 9,
#    'dealer_name': 'Shift SF - Test Drives Delivered To You',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '5YJSA1E29JF250636',
#    'provider': None,
#    'provider_name': 'car_gurus',
#    'always_ask_for_zip': False,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '321826608',
#     'remote_dealer_id': '413397',
#     'dealer_name': 'Shift SF - Test Drives Delivered to You',
#     'remote_sku': 'c1011419',
#     'experience': 'regional',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'shift_sf_test_drives_deliveredto_you_two',
#     'dealer_uuid': 'a13d929d-f3f8-417c-9417-128dbb8ab28b',
#     'dealer_group_unique_name': 'shift_cargurus',
#     'dealer_group_uuid': '88c7994e-2ed1-4892-b70f-55ba4c3e5540'},
#    'trim': '75D',
#    'provider_id': 199,
#    'provider_group_id': 231,
#    'experience': 'regional',
#    'regional': True,
#    'badges': {'position0': None, 'position1': 'fresh'},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1642815269,
#    'recent_price_drop': False,
#    'is_hot': False,
#    'href_target': '/listings/5YJYGDEF5MF151264',
#    'vdp_url': '/tesla-model+y#vin=5YJYGDEF5MF151264',
#    'clickoff_url': 'https://www.carmax.com/car/21822179?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 235780748,
#    'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21822179/1.jpg?width=1024&watermark=LYCG_1a',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--yb0XyJHc--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21822179/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#    'lat': 38.27872113250454,
#    'lon': -122.0043812304184,
#    'year': 2021,
#    'make': 'Tesla',
#    'model': 'Model Y',
#    'model_id': 2357,
#    'display_color': '',
#    'price': '$73,998',
#    'price_unformatted': 73998,
#    'mileage': '9,568 Miles',
#    'mileage_unformatted': 9568,
#    'city': 'Fairfield',
#    'state': 'CA',
#    'distance_from_origin': 41,
#    'dealer_name': 'CarMax Fairfield - Now Offering Curbside Pickup And Home Delivery',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '5YJYGDEF5MF151264',
#    'provider': None,
#    'provider_name': 'carmax',
#    'always_ask_for_zip': True,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '5YJYGDEF5MF151264',
#     'remote_dealer_id': '6048',
#     'dealer_name': 'CarMax Fairfield',
#     'remote_sku': '21822179',
#     'experience': 'local',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'carmax_fairfield',
#     'dealer_uuid': '129aa2eb-3d7a-430c-a516-e65841530372',
#     'dealer_group_unique_name': 'carmax',
#     'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#    'trim': 'Performance',
#    'provider_id': 146,
#    'provider_group_id': 149,
#    'experience': 'local',
#    'regional': False,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': False}],
#  'html': {'search_results': '<a class="AL-vehicle-item -small-md -stacked-sm -stacked-xs -popout-action" href="/tesla-model+3#vin=5YJ3E1EB4JF094546"><div class=\'photo\'>\n<div class=\'AL-vehicle-photo\'>\n<div class=\'viewed-overlay hidden\'></div>\n<div class=\'photo-overlay\'></div>\n<div class=\'overlay-menu\' data-menu>\n<div class=\'-favorite -results-gtsm item\' data-action=\'favorite\'></div>\n</div>\n<div class=\'photo\' style=\'background-image: url(https://images.autolist.com/image/fetch/s--dPaVpWMF--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2021/12/08/18/14/2018_tesla_model_3-pic-3933473144524356802-1024x768.jpeg)\' title=\'used 2018 Tesla Model 3 Long Range Blue 5YJ3E1EB4JF094546\'></div>\n</div>\n<div class=\'badges-container\'>\n<div class=\'outer-container\'>\n<div class=\'\' data-spot=\'0\'>\n\n</div>\n<div class=\'\' data-spot=\'1\'>\n\n</div>\n</div>\n</div>\n</div>\n<div class=\'details\'>\n<h3 class=\'AL-vehicle-primary-details -small-sm -small-xs\'>\n<div class=\'description\'>\n<div class=\'headline\'>2018 Tesla Model 3 Long Range</div>\n<div class=\'subtext\'>\n35,226 Miles\n<span class=\'divider\'>\n|\n</span>\n<span class=\'location\'>Online Only</span>\n</div>\n</div>\n<div class=\'pricing\'>\n<div class=\'headline\'>$45,950</div>\n<div class=\'monthly-payment\' data-menu data-monthly-payment>\n<span class=\'info-link\' href=\'javascript:void(0);\'>\nest. $662/mo\n<i></i>\n</span>\n</div>\n</div>\n</h3>\n<div class=\'AL-vehicle-secondary-details -small-sm -small-xs\' data-menu>\n<div class=\'action\'>\n<span class=\'\' data-action=\'track price\'>\nTrack Price\n</span>\n<span class=\'popout-item\' data-action=\'check availability\'>\nCheck Availability\n</span>\n</div>\n</div>\n</div>\n</a>\n<a class="AL-vehicle-item -small-md -stacked-sm -stacked-xs -popout-action" href="/tesla-model+3#vin=5YJ3E1EB4LF650017"><div class=\'photo\'>\n<div class=\'AL-vehicle-photo\'>\n<div class=\'viewed-overlay hidden\'></div>\n<div class=\'photo-overlay\'></div>\n<div class=\'overlay-menu\' data-menu>\n<div class=\'-favorite -results-gtsm item\' data-action=\'favorite\'></div>\n</div>\n<div class=\'photo\' style=\'background-image: url(https://images.autolist.com/image/fetch/s--qOc0JqDA--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2021/12/31/08/46/2020_tesla_model_3-pic-8934864150452044949-1024x768.jpeg)\' title=\'used 2020 Tesla Model 3 Long Range White 5YJ3E1EB4LF650017\'></div>\n</div>\n<div class=\'badges-container\'>\n<div class=\'outer-container\'>\n<div class=\'\' data-spot=\'0\'>\n\n</div>\n<div class=\'\' data-spot=\'1\'>\n\n</div>\n</div>\n</div>\n</div>\n<div class=\'details\'>\n<h3 class=\'AL-vehicle-primary-details -small-sm -small-xs\'>\n<div class=\'description\'>\n<div class=\'headline\'>2020 Tesla Model 3 Long Range</div>\n<div class=\'subtext\'>\n10,640 Miles\n<span class=\'divider\'>\n|\n</span>\n<span class=\'location\'>Online Only</span>\n</div>\n</div>\n<div class=\'pricing\'>\n<div class=\'headline\'>$52,850</div>\n<div class=\'monthly-payment\' data-menu data-monthly-payment>\n<span class=\'info-link\' href=\'javascript:void(0);\'>\nest. $762/mo\n<i></i>\n</span>\n</div>\n</div>\n</h3>\n<div class=\'AL-vehicle-secondary-details -small-sm -small-xs\' data-menu>\n<div class=\'action\'>\n<span class=\'\' data-action=\'track price\'>\nTrack Price\n</span>\n<span class=\'popout-item\' data-action=\'check availability\'>\nCheck Availability\n</span>\n</div>\n</div>\n</div>\n</a>\n<a class="AL-vehicle-item -small-md -stacked-sm -stacked-xs -popout-action" href="/tesla-model+3#vin=5YJ3E1EA9JF020658"><div class=\'photo\'>\n<div class=\'AL-vehicle-photo\'>\n<div class=\'viewed-overlay hidden\'></div>\n<div class=\'photo-overlay\'></div>\n<div class=\'overlay-menu\' data-menu>\n<div class=\'-favorite -results-gtsm item\' data-action=\'favorite\'></div>\n</div>\n<div class=\'photo\' data-background-image=\'https://images.autolist.com/image/fetch/s--rA ...
#   'pagination': '<ul><li class="previous disabled"><a>Previous</a></li><li class="selected"><a>1</a></li><li data-page="2"><a>2</a></li><li data-page="3"><a>3</a></li><li data-page="4"><a>...</a></li><li data-page="61"><a>61</a></li><li data-page="62"><a>62</a></li><li data-page="2" class="next"><a>Next</a></li></ul>'}}

# %%
type(response.json())
# Out:
# dict

# %% [markdown]
# #### Step 5 - Output Keys

# %%
result_json = response.json()

# %%
response.json().keys()
# Out:
# dict_keys(['total_results_count', 'make_model_name', 'trims', 'ad_info', 'search_results', 'html'])

# %% [markdown]
# #### Step 6 - Find your Data

# %%
#model
#mileage
#year
#dealer name
#price

# %%
response.json()['search_results']
# Out:
# [{'available_nationwide': False,
#   'created_at': 1636428396,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/5YJXCAE40GF012264',
#   'vdp_url': '/tesla-model+x#vin=5YJXCAE40GF012264',
#   'clickoff_url': '',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 231108376,
#   'primary_photo_url': 'https://static.cargurus.com/images/forsale/2022/01/04/19/33/2016_tesla_model_x-pic-1913449488836346646-1024x768.jpeg',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--8mVcBczn--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2022/01/04/19/33/2016_tesla_model_x-pic-1913449488836346646-1024x768.jpeg',
#   'lat': 37.3233,
#   'lon': -121.958,
#   'year': 2016,
#   'make': 'Tesla',
#   'model': 'Model X',
#   'model_id': 2101,
#   'display_color': '',
#   'price': '$74,999',
#   'price_unformatted': 74999,
#   'mileage': '45,530 Miles',
#   'mileage_unformatted': 45530,
#   'city': 'San Jose',
#   'state': 'CA',
#   'distance_from_origin': 40,
#   'dealer_name': 'San Jose Mitsubishi',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 3,
#   'partner_type': 'metasearch',
#   'vin': '5YJXCAE40GF012264',
#   'provider': None,
#   'provider_name': 'car_gurus',
#   'always_ask_for_zip': False,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '316457174',
#    'remote_dealer_id': '439186',
#    'dealer_name': None,
#    'remote_sku': '10918',
#    'experience': 'local',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': None,
#    'dealer_uuid': None,
#    'dealer_group_unique_name': None,
#    'dealer_group_uuid': None},
#   'trim': 'P90D',
#   'provider_id': 199,
#   'provider_group_id': 228,
#   'experience': 'local',
#   'regional': False,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': True},
#  {'available_nationwide': False,
#   'created_at': 1640280834,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/5YJ3E1EA6JF077285',
#   'vdp_url': '/tesla-model+3#vin=5YJ3E1EA6JF077285',
#   'clickoff_url': '',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 234036897,
#   'primary_photo_url': 'https://static.cargurus.com/images/forsale/2022/01/04/02/58/2018_tesla_model_3-pic-8272874169416232735-1024x768.jpeg',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--5NOXsS_L--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2022/01/04/02/58/2018_tesla_model_3-pic-8272874169416232735-1024x768.jpeg',
#   'lat': 37.9645,
#   'lon': -122.513,
#   'year': 2018,
#   'make': 'Tesla',
#   'model': 'Model 3',
#   'model_id': 2217,
#   'display_color': '',
#   'price': '$44,900',
#   'price_unformatted': 44900,
#   'mileage': '36,598 Miles',
#   'mileage_unformatted': 36598,
#   'city': 'San Rafael',
#   'state': 'CA',
#   'distance_from_origin': 14,
#   'dealer_name': 'Toyota Marin',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 3,
#   'partner_type': 'metasearch',
#   'vin': '5YJ3E1EA6JF077285',
#   'provider': None,
#   'provider_name': 'car_gurus',
#   'always_ask_for_zip': False,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '319803943',
#    'remote_dealer_id': '54140',
#    'dealer_name': None,
#    'remote_sku': 'SP17843',
#    'experience': 'local',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': None,
#    'dealer_uuid': None,
#    'dealer_group_unique_name': None,
#    'dealer_group_uuid': None},
#   'trim': 'Long Range',
#   'provider_id': 199,
#   'provider_group_id': 228,
#   'experience': 'local',
#   'regional': False,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': True},
#  {'available_nationwide': False,
#   'created_at': 1642011742,
#   'recent_price_drop': True,
#   'is_hot': False,
#   'href_target': '/listings/5YJ3E1EB8KF408698',
#   'vdp_url': '/tesla-model+3#vin=5YJ3E1EB8KF408698',
#   'clickoff_url': '',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 235161507,
#   'primary_photo_url': 'https://static.cargurus.com/images/forsale/2022/01/18/04/10/2019_tesla_model_3-pic-5410631494234443811-1024x768.jpeg',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--Udp6UV2t--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2022/01/18/04/10/2019_tesla_model_3-pic-5410631494234443811-1024x768.jpeg',
#   'lat': 37.7488,
#   'lon': -122.204,
#   'year': 2019,
#   'make': 'Tesla',
#   'model': 'Model 3',
#   'model_id': 2217,
#   'display_color': '',
#   'price': '$52,930',
#   'price_unformatted': 52930,
#   'mileage': '41,158 Miles',
#   'mileage_unformatted': 41158,
#   'city': 'Oakland',
#   'state': 'CA',
#   'distance_from_origin': 11,
#   'dealer_name': 'Audi Oakland',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 3,
#   'partner_type': 'metasearch',
#   'vin': '5YJ3E1EB8KF408698',
#   'provider': None,
#   'provider_name': 'car_gurus',
#   'always_ask_for_zip': False,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '320999438',
#    'remote_dealer_id': '63786',
#    'dealer_name': None,
#    'remote_sku': 'KF408698P',
#    'experience': 'local',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': None,
#    'dealer_uuid': None,
#    'dealer_group_unique_name': None,
#    'dealer_group_uuid': None},
#   'trim': 'Performance',
#   'provider_id': 199,
#   'provider_group_id': 228,
#   'experience': 'local',
#   'regional': False,
#   'badges': {'position0': None, 'position1': 'price_drop'},
#   'quick_picks_eligible': True},
#  {'available_nationwide': False,
#   'created_at': 1641010850,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/5YJ3E1EB9MF070232',
#   'vdp_url': '/tesla-model+3#vin=5YJ3E1EB9MF070232',
#   'clickoff_url': 'https://www.carmax.com/car/21744418?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 234530536,
#   'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21744418/1.jpg?width=1024&watermark=LYCG_1a',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--qgd6RSR2--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21744418/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#   'lat': 37.2706246070151,
#   'lon': -121.8513164222633,
#   'year': 2021,
#   'make': 'Tesla',
#   'model': 'Model 3',
#   'model_id': 2217,
#   'display_color': '',
#   'price': '$61,998',
#   'price_unformatted': 61998,
#   'mileage': '4,833 Miles',
#   'mileage_unformatted': 4833,
#   'city': 'San Jose',
#   'state': 'CA',
#   'distance_from_origin': 46,
#   'dealer_name': 'CarMax Capitol Expressway - Now Open',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 15,
#   'partner_type': 'dealer_direct',
#   'vin': '5YJ3E1EB9MF070232',
#   'provider': None,
#   'provider_name': 'carmax',
#   'always_ask_for_zip': True,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '5YJ3E1EB9MF070232',
#    'remote_dealer_id': '6072',
#    'dealer_name': 'CarMax Capitol Expressway',
#    'remote_sku': '21744418',
#    'experience': 'local',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': 'carmax_capitol_expressway',
#    'dealer_uuid': '59dddca6-1a7a-4f7c-a382-e8af52fdc9d8',
#    'dealer_group_unique_name': 'carmax',
#    'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#   'trim': 'Long Range',
#   'provider_id': 146,
#   'provider_group_id': 149,
#   'experience': 'local_if_nearby',
#   'regional': False,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': False},
#  {'available_nationwide': False,
#   'created_at': 1638036145,
#   'recent_price_drop': True,
#   'is_hot': False,
#   'href_target': '/listings/5YJ3E1EAXJF169483',
#   'vdp_url': '/tesla-model+3#vin=5YJ3E1EAXJF169483',
#   'clickoff_url': '',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 232326056,
#   'primary_photo_url': 'https://static.cargurus.com/images/forsale/2022/01/19/03/07/2018_tesla_model_3-pic-7744575740210149374-1024x768.jpeg',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--fTaa30c2--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2022/01/19/03/07/2018_tesla_model_3-pic-7744575740210149374-1024x768.jpeg',
#   'lat': 37.7488,
#   'lon': -122.204,
#   'year': 2018,
#   'make': 'Tesla',
#   'model': 'Model 3',
#   'model_id': 2217,
#   'display_color': '',
#   'price': '$47,565',
#   'price_unformatted': 47565,
#   'mileage': '12,285 Miles',
#   'mileage_unformatted': 12285,
#   'city': 'Oakland',
#   'state': 'CA',
#   'distance_from_origin': 11,
#   'dealer_name': 'Audi Oakland',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 3,
#   'partner_type': 'metasearch',
#   'vin': '5YJ3E1EAXJF169483',
#   'provider': None,
#   'provider_name': 'car_gurus',
#   'always_ask_for_zip': False,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '317806861',
#    'remote_dealer_id': '63786',
#    'dealer_name': None,
#    'remote_sku': 'JF169483P',
#    'experience': 'local',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': None,
#    'dealer_uuid': None,
#    'dealer_group_unique_name': None,
#    'dealer_group_uuid': None},
#   'trim': 'Standard',
#   'provider_id': 199,
#   'provider_group_id': 228,
#   'experience': 'local',
#   'regional': False,
#   'badges': {'position0': None, 'position1': 'price_drop'},
#   'quick_picks_eligible': True},
#  {'available_nationwide': False,
#   'created_at': 1642530941,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/5YJXCAE26JF090828',
#   'vdp_url': '/tesla-model+x#vin=5YJXCAE26JF090828',
#   'clickoff_url': '',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 235542000,
#   'primary_photo_url': 'https://static.cargurus.com/images/forsale/2022/01/18/01/35/2018_tesla_model_x-pic-1140924409467684468-1024x768.jpeg',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--65hP_EZt--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2022/01/18/01/35/2018_tesla_model_x-pic-1140924409467684468-1024x768.jpeg',
#   'lat': 37.9659,
#   'lon': -122.052,
#   'year': 2018,
#   'make': 'Tesla',
#   'model': 'Model X',
#   'model_id': 2101,
#   'display_color': '',
#   'price': '$82,990',
#   'price_unformatted': 82990,
#   'mileage': '36,983 Miles',
#   'mileage_unformatted': 36983,
#   'city': 'Concord',
#   'state': 'CA',
#   'distance_from_origin': 23,
#   'dealer_name': 'Elite Motor Cars',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 3,
#   'partner_type': 'metasearch',
#   'vin': '5YJXCAE26JF090828',
#   'provider': None,
#   'provider_name': 'car_gurus',
#   'always_ask_for_zip': False,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '321437511',
#    'remote_dealer_id': '385937',
#    'dealer_name': None,
#    'remote_sku': '006162',
#    'experience': 'local',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': None,
#    'dealer_uuid': None,
#    'dealer_group_unique_name': None,
#    'dealer_group_uuid': None},
#   'trim': '75D',
#   'provider_id': 199,
#   'provider_group_id': 228,
#   'experience': 'local',
#   'regional': False,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': True},
#  {'available_nationwide': False,
#   'created_at': 1640280834,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/5YJ3E1EA4JF034743',
#   'vdp_url': '/tesla-model+3#vin=5YJ3E1EA4JF034743',
#   'clickoff_url': '',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 234036896,
#   'primary_photo_url': 'https://static.cargurus.com/images/forsale/2021/12/28/03/45/2018_tesla_model_3-pic-7047892888723887831-1024x768.jpeg',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--dm-iZaJU--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2021/12/28/03/45/2018_tesla_model_3-pic-7047892888723887831-1024x768.jpeg',
#   'lat': 37.9645,
#   'lon': -122.513,
#   'year': 2018,
#   'make': 'Tesla',
#   'model': 'Model 3',
#   'model_id': 2217,
#   'display_color': '',
#   'price': '$46,700',
#   'price_unformatted': 46700,
#   'mileage': '19,140 Miles',
#   'mileage_unformatted': 19140,
#   'city': 'San Rafael',
#   'state': 'CA',
#   'distance_from_origin': 14,
#   'dealer_name': 'Toyota Marin',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 3,
#   'partner_type': 'metasearch',
#   'vin': '5YJ3E1EA4JF034743',
#   'provider': None,
#   'provider_name': 'car_gurus',
#   'always_ask_for_zip': False,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '319803944',
#    'remote_dealer_id': '54140',
#    'dealer_name': None,
#    'remote_sku': 'SP17841',
#    'experience': 'local',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': None,
#    'dealer_uuid': None,
#    'dealer_group_unique_name': None,
#    'dealer_group_uuid': None},
#   'trim': 'Long Range',
#   'provider_id': 199,
#   'provider_group_id': 228,
#   'experience': 'local',
#   'regional': False,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': True},
#  {'available_nationwide': False,
#   'created_at': 1633532794,
#   'recent_price_drop': True,
#   'is_hot': False,
#   'href_target': '/listings/5YJSA1E6XMF431722',
#   'vdp_url': '/tesla-model+s#vin=5YJSA1E6XMF431722',
#   'clickoff_url': '',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 228952752,
#   'primary_photo_url': 'https://static.cargurus.com/images/forsale/2021/10/29/21/20/2021_tesla_model_s-pic-8691913956955880569-1024x768.jpeg',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--uWHxZ_oZ--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2021/10/29/21/20/2021_tesla_model_s-pic-8691913956955880569-1024x768.jpeg',
#   'lat': 37.4513878236494,
#   'lon': -122.118228547276,
#   'year': 2021,
#   'make': 'Tesla',
#   'model': 'Model S',
#   'model_id': 2006,
#   'display_color': '',
#   'price': '$137,910',
#   'price_unformatted': 137910,
#   'mileage': '1,089 Miles',
#   'mileage_unformatted': 1089,
#   'city': 'Palo Alto',
#   'state': 'CA',
#   'distance_from_origin': 27,
#   'dealer_name': 'Audi Palo Alto',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 3,
#   'partner_type': 'metasearch',
#   'vin': '5YJSA1E6XMF431722',
#   'provider': None,
#   'provider_name': 'car_gurus',
#   'always_ask_for_zip': False,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '314066650',
#    'remote_dealer_id': '63777',
#    'dealer_name': None,
#    'remote_sku': 'MF431722U',
#    'experience': 'local',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': None,
#    'dealer_uuid': None,
#    'dealer_group_unique_name': None,
#    'dealer_group_uuid': None},
#   'trim': 'Plaid+',
#   'provider_id': 199,
#   'provider_group_id': 228,
#   'experience': 'local',
#   'regional': False,
#   'badges': {'position0': None, 'position1': 'price_drop'},
#   'quick_picks_eligible': True},
#  {'available_nationwide': False,
#   'created_at': 1640283591,
#   'recent_price_drop': True,
#   'is_hot': False,
#   'href_target': '/listings/5YJ3E1EAXLF611973',
#   'vdp_url': '/tesla-model+3#vin=5YJ3E1EAXLF611973',
#   'clickoff_url': 'https://www.carmax.com/car/21744168?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 234047488,
#   'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21744168/1.jpg?width=1024&watermark=LYCG_1a',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--5JjvX6E_--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21744168/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#   'lat': 37.2706246070151,
#   'lon': -121.8513164222633,
#   'year': 2020,
#   'make': 'Tesla',
#   'model': 'Model 3',
#   'model_id': 2217,
#   'display_color': '',
#   'price': '$48,998',
#   'price_unformatted': 48998,
#   'mileage': '8,596 Miles',
#   'mileage_unformatted': 8596,
#   'city': 'San Jose',
#   'state': 'CA',
#   'distance_from_origin': 46,
#   'dealer_name': 'CarMax Capitol Expressway - Now Open',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 15,
#   'partner_type': 'dealer_direct',
#   'vin': '5YJ3E1EAXLF611973',
#   'provider': None,
#   'provider_name': 'carmax',
#   'always_ask_for_zip': True,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '5YJ3E1EAXLF611973',
#    'remote_dealer_id': '6072',
#    'dealer_name': 'CarMax Capitol Expressway',
#    'remote_sku': '21744168',
#    'experience': 'local',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': 'carmax_capitol_expressway',
#    'dealer_uuid': '59dddca6-1a7a-4f7c-a382-e8af52fdc9d8',
#    'dealer_group_unique_name': 'carmax',
#    'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#   'trim': 'Standard Range Plus',
#   'provider_id': 146,
#   'provider_group_id': 149,
#   'experience': 'local_if_nearby',
#   'regional': False,
#   'badges': {'position0': None, 'position1': 'price_drop'},
#   'quick_picks_eligible': False},
#  {'available_nationwide': False,
#   'created_at': 1641485019,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/5YJ3E1EBXLF803080',
#   'vdp_url': '/tesla-model+3#vin=5YJ3E1EBXLF803080',
#   'clickoff_url': 'https://www.shift.com/car/c173240?utm_source=Autolist&utm_medium=listing&utm_campaign=deeplink',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 234786138,
#   'primary_photo_url': 'https://static.cargurus.com/images/forsale/2021/12/11/19/11/2020_tesla_model_3-pic-6565696217583196499-1024x768.jpeg',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--tZO5mZf3--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2021/12/11/19/11/2020_tesla_model_3-pic-6565696217583196499-1024x768.jpeg',
#   'lat': 37.6397,
#   'lon': -122.416,
#   'year': 2020,
#   'make': 'Tesla',
#   'model': 'Model 3',
#   'model_id': 2217,
#   'display_color': '',
#   'price': '$52,350',
#   'price_unformatted': 52350,
#   'mileage': '2,927 Miles',
#   'mileage_unformatted': 2927,
#   'city': 'South San Francisco',
#   'state': 'CA',
#   'distance_from_origin': 9,
#   'dealer_name': 'Shift SF - Test Drives Delivered To You',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 15,
#   'partner_type': 'dealer_direct',
#   'vin': '5YJ3E1EBXLF803080',
#   'provider': None,
#   'provider_name': 'car_gurus',
#   'always_ask_for_zip': False,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '318749489',
#    'remote_dealer_id': '413397',
#    'dealer_name': 'Shift SF - Test Drives Delivered to You',
#    'remote_sku': 'c173240',
#    'experience': 'regional',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': 'shift_sf_test_drives_deliveredto_you_two',
#    'dealer_uuid': 'a13d929d-f3f8-417c-9417-128dbb8ab28b',
#    'dealer_group_unique_name': 'shift_cargurus',
#    'dealer_group_uuid': '88c7994e-2ed1-4892-b70f-55ba4c3e5540'},
#   'trim': 'Long Range',
#   'provider_id': 199,
#   'provider_group_id': 231,
#   'experience': 'regional',
#   'regional': True,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': False},
#  {'available_nationwide': False,
#   'created_at': 1633793557,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/5YJ3E1EA2JF156551',
#   'vdp_url': '/tesla-model+3#vin=5YJ3E1EA2JF156551',
#   'clickoff_url': '',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 229215189,
#   'primary_photo_url': 'https://static.cargurus.com/images/forsale/2022/01/10/17/13/2018_tesla_model_3-pic-1088615791975529726-1024x768.jpeg',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--4TnZliEQ--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2022/01/10/17/13/2018_tesla_model_3-pic-1088615791975529726-1024x768.jpeg',
#   'lat': 37.9991,
#   'lon': -122.054,
#   'year': 2018,
#   'make': 'Tesla',
#   'model': 'Model 3',
#   'model_id': 2217,
#   'display_color': '',
#   'price': '$48,750',
#   'price_unformatted': 48750,
#   'mileage': '20,990 Miles',
#   'mileage_unformatted': 20990,
#   'city': 'Concord',
#   'state': 'CA',
#   'distance_from_origin': 25,
#   'dealer_name': 'Future Chrysler Dodge Jeep Ram Of Concord',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 3,
#   'partner_type': 'metasearch',
#   'vin': '5YJ3E1EA2JF156551',
#   'provider': None,
#   'provider_name': 'car_gurus',
#   'always_ask_for_zip': False,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '314233696',
#    'remote_dealer_id': '438930',
#    'dealer_name': None,
#    'remote_sku': 'P50489',
#    'experience': 'local',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': None,
#    'dealer_uuid': None,
#    'dealer_group_unique_name': None,
#    'dealer_group_uuid': None},
#   'trim': 'Standard',
#   'provider_id': 199,
#   'provider_group_id': 228,
#   'experience': 'local',
#   'regional': False,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': True},
#  {'available_nationwide': False,
#   'created_at': 1642139459,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/5YJ3E1EB8MF862288',
#   'vdp_url': '/tesla-model+3#vin=5YJ3E1EB8MF862288',
#   'clickoff_url': '',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 235283148,
#   'primary_photo_url': 'https://static.cargurus.com/images/forsale/2022/01/13/20/09/2021_tesla_model_3-pic-235546917707159760-1024x768.jpeg',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--6eQxB-fO--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2022/01/13/20/09/2021_tesla_model_3-pic-235546917707159760-1024x768.jpeg',
#   'lat': 37.67825483705325,
#   'lon': -121.9129676305049,
#   'year': 2021,
#   'make': 'Tesla',
#   'model': 'Model 3',
#   'model_id': 2217,
#   'display_color': '',
#   'price': '$54,998',
#   'price_unformatted': 54998,
#   'mileage': '23,085 Miles',
#   'mileage_unformatted': 23085,
#   'city': 'Pleasanton',
#   'state': 'CA',
#   'distance_from_origin': 28,
#   'dealer_name': 'CarMax Pleasanton - Now Offering Curbside Pickup And Home Delivery',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 3,
#   'partner_type': 'metasearch',
#   'vin': '5YJ3E1EB8MF862288',
#   'provider': None,
#   'provider_name': 'car_gurus',
#   'always_ask_for_zip': False,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '321180927',
#    'remote_dealer_id': '384892',
#    'dealer_name': None,
#    'remote_sku': '22099495',
#    'experience': 'local',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': None,
#    'dealer_uuid': None,
#    'dealer_group_unique_name': None,
#    'dealer_group_uuid': None},
#   'trim': 'Long Range',
#   'provider_id': 199,
#   'provider_group_id': 228,
#   'experience': 'local',
#   'regional': False,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': True},
#  {'available_nationwide': False,
#   'created_at': 1642131958,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/5YJSA1CN8DFP22536',
#   'vdp_url': '/tesla-model+s#vin=5YJSA1CN8DFP22536',
#   'clickoff_url': '',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 235274932,
#   'primary_photo_url': 'https://static.cargurus.com/images/forsale/2022/01/14/23/18/2013_tesla_model_s-pic-4070981846818503423-1024x768.jpeg',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--CB7oS8dk--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2022/01/14/23/18/2013_tesla_model_s-pic-4070981846818503423-1024x768.jpeg',
#   'lat': 37.3708,
#   'lon': -122.044,
#   'year': 2013,
#   'make': 'Tesla',
#   'model': 'Model S',
#   'model_id': 2006,
#   'display_color': '',
#   'price': '$42,991',
#   'price_unformatted': 42991,
#   'mileage': '43,407 Miles',
#   'mileage_unformatted': 43407,
#   'city': 'Sunnyvale',
#   'state': 'CA',
#   'distance_from_origin': 34,
#   'dealer_name': 'Toyota Sunnyvale',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 3,
#   'partner_type': 'metasearch',
#   'vin': '5YJSA1CN8DFP22536',
#   'provider': None,
#   'provider_name': 'car_gurus',
#   'always_ask_for_zip': False,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '321164806',
#    'remote_dealer_id': '54125',
#    'dealer_name': None,
#    'remote_sku': '213402A',
#    'experience': 'local',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': None,
#    'dealer_uuid': None,
#    'dealer_group_unique_name': None,
#    'dealer_group_uuid': None},
#   'trim': 'Base',
#   'provider_id': 199,
#   'provider_group_id': 227,
#   'experience': 'local',
#   'regional': False,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': True},
#  {'available_nationwide': False,
#   'created_at': 1640879330,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/5YJXCDE20HF044679',
#   'vdp_url': '/tesla-model+x#vin=5YJXCDE20HF044679',
#   'clickoff_url': '',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 234392072,
#   'primary_photo_url': 'https://static.cargurus.com/images/forsale/2022/01/15/01/42/2017_tesla_model_x-pic-7111945539997451800-1024x768.jpeg',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--H26q_CUn--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2022/01/15/01/42/2017_tesla_model_x-pic-7111945539997451800-1024x768.jpeg',
#   'lat': 37.96719,
#   'lon': -122.517662,
#   'year': 2017,
#   'make': 'Tesla',
#   'model': 'Model X',
#   'model_id': 2101,
#   'display_color': '',
#   'price': '$72,990',
#   'price_unformatted': 72990,
#   'mileage': '43,771 Miles',
#   'mileage_unformatted': 43771,
#   'city': 'San Rafael',
#   'state': 'CA',
#   'distance_from_origin': 14,
#   'dealer_name': 'INFINITI Of Marin',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 3,
#   'partner_type': 'metasearch',
#   'vin': '5YJXCDE20HF044679',
#   'provider': None,
#   'provider_name': 'car_gurus',
#   'always_ask_for_zip': False,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '320186161',
#    'remote_dealer_id': '346573',
#    'dealer_name': None,
#    'remote_sku': 'I19830',
#    'experience': 'local',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': None,
#    'dealer_uuid': None,
#    'dealer_group_unique_name': None,
#    'dealer_group_uuid': None},
#   'trim': '90D',
#   'provider_id': 199,
#   'provider_group_id': 228,
#   'experience': 'local',
#   'regional': False,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': True},
#  {'available_nationwide': False,
#   'created_at': 1642703553,
#   'recent_price_drop': None,
#   'is_hot': False,
#   'href_target': '/listings/5YJ3E1EB0JF097685',
#   'vdp_url': '/tesla-model+3#vin=5YJ3E1EB0JF097685',
#   'clickoff_url': '',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 235696608,
#   'primary_photo_url': 'https://static.cargurus.com/images/forsale/2022/01/20/08/59/2018_tesla_model_3-pic-8064932346227003602-1024x768.jpeg',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--RE_zFjvl--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2022/01/20/08/59/2018_tesla_model_3-pic-8064932346227003602-1024x768.jpeg',
#   'lat': 37.4503,
#   'lon': -122.119,
#   'year': 2018,
#   'make': 'Tesla',
#   'model': 'Model 3',
#   'model_id': 2217,
#   'display_color': '',
#   'price': '$47,778',
#   'price_unformatted': 47778,
#   'mileage': '17,363 Miles',
#   'mileage_unformatted': 17363,
#   'city': 'Palo Alto',
#   'state': 'CA',
#   'distance_from_origin': 27,
#   'dealer_name': 'Audi Palo Alto',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 3,
#   'partner_type': 'metasearch',
#   'vin': '5YJ3E1EB0JF097685',
#   'provider': None,
#   'provider_name': 'car_gurus',
#   'always_ask_for_zip': False,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '321621165',
#    'remote_dealer_id': '63777',
#    'dealer_name': None,
#    'remote_sku': 'JF097685P',
#    'experience': 'local',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': None,
#    'dealer_uuid': None,
#    'dealer_group_unique_name': None,
#    'dealer_group_uuid': None},
#   'trim': 'Long Range',
#   'provider_id': 199,
#   'provider_group_id': 228,
#   'experience': 'local',
#   'regional': False,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': True},
#  {'available_nationwide': False,
#   'created_at': 1639446637,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/5YJ3E1EB7LF667216',
#   'vdp_url': '/tesla-model+3#vin=5YJ3E1EB7LF667216',
#   'clickoff_url': '',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 233364260,
#   'primary_photo_url': 'https://static.cargurus.com/images/forsale/2022/01/22/16/12/2020_tesla_model_3-pic-7503649615381840300-1024x768.jpeg',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--_Q6qS6N8--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2022/01/22/16/12/2020_tesla_model_3-pic-7503649615381840300-1024x768.jpeg',
#   'lat': 37.3231,
#   'lon': -121.982,
#   'year': 2020,
#   'make': 'Tesla',
#   'model': 'Model 3',
#   'model_id': 2217,
#   'display_color': '',
#   'price': '$49,390',
#   'price_unformatted': 49390,
#   'mileage': '40,319 Miles',
#   'mileage_unformatted': 40319,
#   'city': 'San Jose',
#   'state': 'CA',
#   'distance_from_origin': 39,
#   'dealer_name': 'Mercedes-Benz Of Stevens Creek',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 3,
#   'partner_type': 'metasearch',
#   'vin': '5YJ3E1EB7LF667216',
#   'provider': None,
#   'provider_name': 'car_gurus',
#   'always_ask_for_zip': False,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '319025700',
#    'remote_dealer_id': '279348',
#    'dealer_name': None,
#    'remote_sku': 'LF667216',
#    'experience': 'local',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': None,
#    'dealer_uuid': None,
#    'dealer_group_unique_name': None,
#    'dealer_group_uuid': None},
#   'trim': 'Long Range',
#   'provider_id': 199,
#   'provider_group_id': 228,
#   'experience': 'local',
#   'regional': False,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': True},
#  {'available_nationwide': False,
#   'created_at': 1639151824,
#   'recent_price_drop': True,
#   'is_hot': False,
#   'href_target': '/listings/5YJ3E1EB8KF421502',
#   'vdp_url': '/tesla-model+3#vin=5YJ3E1EB8KF421502',
#   'clickoff_url': '',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 233173344,
#   'primary_photo_url': 'https://static.cargurus.com/images/forsale/2021/12/29/20/40/2019_tesla_model_3-pic-5400811168639377317-1024x768.jpeg',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--27PaN3wp--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2021/12/29/20/40/2019_tesla_model_3-pic-5400811168639377317-1024x768.jpeg',
#   'lat': 37.7406,
#   'lon': -122.198,
#   'year': 2019,
#   'make': 'Tesla',
#   'model': 'Model 3',
#   'model_id': 2217,
#   'display_color': '',
#   'price': '$49,564',
#   'price_unformatted': 49564,
#   'mileage': '36,325 Miles',
#   'mileage_unformatted': 36325,
#   'city': 'Oakland',
#   'state': 'CA',
#   'distance_from_origin': 12,
#   'dealer_name': 'One Toyota Of Oakland',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 3,
#   'partner_type': 'metasearch',
#   'vin': '5YJ3E1EB8KF421502',
#   'provider': None,
#   'provider_name': 'car_gurus',
#   'always_ask_for_zip': False,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '318827220',
#    'remote_dealer_id': '280270',
#    'dealer_name': None,
#    'remote_sku': 'P10918',
#    'experience': 'local',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': None,
#    'dealer_uuid': None,
#    'dealer_group_unique_name': None,
#    'dealer_group_uuid': None},
#   'trim': 'Long Range',
#   'provider_id': 199,
#   'provider_group_id': 228,
#   'experience': 'local',
#   'regional': False,
#   'badges': {'position0': None, 'position1': 'price_drop'},
#   'quick_picks_eligible': True},
#  {'available_nationwide': False,
#   'created_at': 1633485626,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/5YJ3E1EA2KF399407',
#   'vdp_url': '/tesla-model+3#vin=5YJ3E1EA2KF399407',
#   'clickoff_url': '',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 228920453,
#   'primary_photo_url': 'https://static.cargurus.com/images/forsale/2022/01/04/19/33/2019_tesla_model_3-pic-5060339496279208640-1024x768.jpeg',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--DZFN0nIL--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2022/01/04/19/33/2019_tesla_model_3-pic-5060339496279208640-1024x768.jpeg',
#   'lat': 37.3233,
#   'lon': -121.958,
#   'year': 2019,
#   'make': 'Tesla',
#   'model': 'Model 3',
#   'model_id': 2217,
#   'display_color': '',
#   'price': '$40,999',
#   'price_unformatted': 40999,
#   'mileage': '54,647 Miles',
#   'mileage_unformatted': 54647,
#   'city': 'San Jose',
#   'state': 'CA',
#   'distance_from_origin': 40,
#   'dealer_name': 'San Jose Mitsubishi',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 3,
#   'partner_type': 'metasearch',
#   'vin': '5YJ3E1EA2KF399407',
#   'provider': None,
#   'provider_name': 'car_gurus',
#   'always_ask_for_zip': False,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '314002738',
#    'remote_dealer_id': '439186',
#    'dealer_name': None,
#    'remote_sku': '10863',
#    'experience': 'local',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': None,
#    'dealer_uuid': None,
#    'dealer_group_unique_name': None,
#    'dealer_group_uuid': None},
#   'trim': 'Standard Range',
#   'provider_id': 199,
#   'provider_group_id': 228,
#   'experience': 'local',
#   'regional': False,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': True},
#  {'available_nationwide': False,
#   'created_at': 1640967799,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/5YJXCAE20GF005393',
#   'vdp_url': '/tesla-model+x#vin=5YJXCAE20GF005393',
#   'clickoff_url': '',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 234476314,
#   'primary_photo_url': 'https://static.cargurus.com/images/forsale/2021/12/30/23/29/2016_tesla_model_x-pic-3426536640722517041-1024x768.jpeg',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--_i7o53u1--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2021/12/30/23/29/2016_tesla_model_x-pic-3426536640722517041-1024x768.jpeg',
#   'lat': 37.9104,
#   'lon': -122.065,
#   'year': 2016,
#   'make': 'Tesla',
#   'model': 'Model X',
#   'model_id': 2101,
#   'display_color': '',
#   'price': '$79,900',
#   'price_unformatted': 79900,
#   'mileage': '48,877 Miles',
#   'mileage_unformatted': 48877,
#   'city': 'Walnut Creek',
#   'state': 'CA',
#   'distance_from_origin': 21,
#   'dealer_name': 'North State Auto Sales',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 3,
#   'partner_type': 'metasearch',
#   'vin': '5YJXCAE20GF005393',
#   'provider': None,
#   'provider_name': 'car_gurus',
#   'always_ask_for_zip': False,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '320280113',
#    'remote_dealer_id': '287296',
#    'dealer_name': None,
#    'remote_sku': '7875',
#    'experience': 'local',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': None,
#    'dealer_uuid': None,
#    'dealer_group_unique_name': None,
#    'dealer_group_uuid': None},
#   'trim': '90D',
#   'provider_id': 199,
#   'provider_group_id': 228,
#   'experience': 'local',
#   'regional': False,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': True},
#  {'available_nationwide': False,
#   'created_at': 1641438830,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/5YJYGDEE9LF020408',
#   'vdp_url': '/tesla-model+y#vin=5YJYGDEE9LF020408',
#   'clickoff_url': '',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 234764043,
#   'primary_photo_url': 'https://static.cargurus.com/images/forsale/2022/01/15/01/59/2020_tesla_model_y-pic-3250537339183639151-1024x768.jpeg',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--Ov_RMvlr--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2022/01/15/01/59/2020_tesla_model_y-pic-3250537339183639151-1024x768.jpeg',
#   'lat': 37.6545,
#   'lon': -122.07,
#   'year': 2020,
#   'make': 'Tesla',
#   'model': 'Model Y',
#   'model_id': 2357,
#   'display_color': '',
#   'price': '$60,999',
#   'price_unformatted': 60999,
#   'mileage': '49,869 Miles',
#   'mileage_unformatted': 49869,
#   'city': 'Hayward',
#   'state': 'CA',
#   'distance_from_origin': 20,
#   'dealer_name': 'Hayward Mitsubishi',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 3,
#   'partner_type': 'metasearch',
#   'vin': '5YJYGDEE9LF020408',
#   'provider': None,
#   'provider_name': 'car_gurus',
#   'always_ask_for_zip': False,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '320590675',
#    'remote_dealer_id': '379284',
#    'dealer_name': None,
#    'remote_sku': '21814',
#    'experience': 'local',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': None,
#    'dealer_uuid': None,
#    'dealer_group_unique_name': None,
#    'dealer_group_uuid': None},
#   'trim': 'Long Range',
#   'provider_id': 199,
#   'provider_group_id': 227,
#   'experience': 'local',
#   'regional': False,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': True}]

# %%
result_item = response.json()['search_results']

# %%
len(result)
# Out:
# 56

# %%
result_item[0]
# Out:
# {'available_nationwide': False,
#  'created_at': 1636428396,
#  'recent_price_drop': False,
#  'is_hot': False,
#  'href_target': '/listings/5YJXCAE40GF012264',
#  'vdp_url': '/tesla-model+x#vin=5YJXCAE40GF012264',
#  'clickoff_url': '',
#  'accepts_leads': True,
#  'open_in_new_window': False,
#  'id': 231108376,
#  'primary_photo_url': 'https://static.cargurus.com/images/forsale/2022/01/04/19/33/2016_tesla_model_x-pic-1913449488836346646-1024x768.jpeg',
#  'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--8mVcBczn--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2022/01/04/19/33/2016_tesla_model_x-pic-1913449488836346646-1024x768.jpeg',
#  'lat': 37.3233,
#  'lon': -121.958,
#  'year': 2016,
#  'make': 'Tesla',
#  'model': 'Model X',
#  'model_id': 2101,
#  'display_color': '',
#  'price': '$74,999',
#  'price_unformatted': 74999,
#  'mileage': '45,530 Miles',
#  'mileage_unformatted': 45530,
#  'city': 'San Jose',
#  'state': 'CA',
#  'distance_from_origin': 40,
#  'dealer_name': 'San Jose Mitsubishi',
#  'show_message_box': None,
#  'email_opt_default': True,
#  'show_financing_checkbox': None,
#  'show_new_mileage': False,
#  'show_thankyou_page': False,
#  'show_rsrp': True,
#  'click_off': False,
#  'pre_check_thankyou': True,
#  'cpl_value': 3,
#  'partner_type': 'metasearch',
#  'vin': '5YJXCAE40GF012264',
#  'provider': None,
#  'provider_name': 'car_gurus',
#  'always_ask_for_zip': False,
#  'listing_id': None,
#  'time_on_market': None,
#  'total_price_change': None,
#  'relative_price_difference': None,
#  'listimate_category': None,
#  'listimate_text': None,
#  'photo_urls': [],
#  'tracking_params': {'id_from_provider': '316457174',
#   'remote_dealer_id': '439186',
#   'dealer_name': None,
#   'remote_sku': '10918',
#   'experience': 'local',
#   'rooftop_unique_name': None,
#   'rooftop_uuid': None,
#   'dealer_unique_name': None,
#   'dealer_uuid': None,
#   'dealer_group_unique_name': None,
#   'dealer_group_uuid': None},
#  'trim': 'P90D',
#  'provider_id': 199,
#  'provider_group_id': 228,
#  'experience': 'local',
#  'regional': False,
#  'badges': {'position0': None, 'position1': None},
#  'quick_picks_eligible': True}

# %%
#model
result_item[0]['model']
# Out:
# 'Model X'

# %%
#mileage
result_item[0]['mileage']
# Out:
# '45,530 Miles'

# %%
#year
result_item[0]['year']
# Out:
# 2016

# %%
#dealer name
result_item[0]['dealer_name']
# Out:
# 'San Jose Mitsubishi'

# %%
#price
result_item[0]['price']
# Out:
# '$74,999'

# %% [markdown]
# #### Step 7 - Put everything together - Loop through results and append data inside a list

# %%
model = []
mileage = []
year = []
dealer_name = []
price = []

for result in result_item:
    
    model.append(result['model'])
    mileage.append(result['mileage'])
    year.append(result['year'])
    dealer_name.append(result['dealer_name'])
    price.append(result['price'])

# %% [markdown]
# #### Step 8 - Pandas Dataframe - Single Page

# %%
test_df = pd.DataFrame({'Model': model,'Mileage': mileage,'Year':year,'Dealer_name':dealer_name,
                        'Price':price})

# %%
test_df
# Out:
#       Model       Mileage  Year  \
# 0   Model X  45,530 Miles  2016
# 1   Model 3  36,598 Miles  2018
# 2   Model 3  41,158 Miles  2019
# 3   Model 3   4,833 Miles  2021
# 4   Model 3  12,285 Miles  2018
# 5   Model X  36,983 Miles  2018
# 6   Model 3  19,140 Miles  2018
# 7   Model S   1,089 Miles  2021
# 8   Model 3   8,596 Miles  2020
# 9   Model 3   2,927 Miles  2020
# 10  Model 3  20,990 Miles  2018
# 11  Model 3  23,085 Miles  2021
# 12  Model S  43,407 Miles  2013
# 13  Model X  43,771 Miles  2017
# 14  Model 3  17,363 Miles  2018
# 15  Model 3  40,319 Miles  2020
# 16  Model 3  36,325 Miles  2019
# 17  Model 3  54,647 Miles  2019
# 18  Model X  48,877 Miles  2016
# 19  Model Y  49,869 Miles  2020
#
#                                           Dealer_name     Price
# 0                                 San Jose Mitsubishi   $74,999
# 1                                        Toyota Marin   $44,900
# 2                                        Audi Oakland   $52,930
# 3                CarMax Capitol Expressway - Now Open   $61,998
# 4                                        Audi Oakland   $47,565
# 5                                    Elite Motor Cars   $82,990
# 6                                        Toyota Marin   $46,700
# 7                                      Audi Palo Alto  $137,910
# 8                CarMax Capitol Expressway - Now Open   $48,998
# 9             Shift SF - Test Drives Delivered To You   $52,350
# 10          Future Chrysler Dodge Jeep Ram Of Concord   $48,750
# 11  CarMax Pleasanton - Now Offering Curbside Pick...   $54,998
# 12                                   Toyota Sunnyvale   $42,991
# 13                                  INFINITI Of Marin   $72,990
# 14                                     Audi Palo Alto   $47,778
# 15                     Mercedes-Benz Of Stevens Creek   $49,390
# 16                              One Toyota Of Oakland   $49,564
# 17                                San Jose Mitsubishi   $40,999
# 18                             North State Auto Sales   $79,900
# 19                                 Hayward Mitsubishi   $60,999

# %%
test_df.to_excel('tesla_single_page.xlsx', index = False )

# %% [markdown]
# #### Step 9 - Scraping Multiple Pages (here: 5pages to get 100 results)

# %%
headers = {
    'authority': 'www.autolist.com',
    'sec-ch-ua': '^\\^Chromium^\\^;v=^\\^94^\\^, ^\\^Google',
    'accept': '*/*',
    'x-requested-with': 'XMLHttpRequest',
    'sec-ch-ua-mobile': '?0',
    'x-autolist-session-guid': 'c9fb9ffb-2c06-4468-a3d0-c26290c6994f',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/94.0.4590.0 Safari/537.36',
    'sec-ch-ua-platform': '^\\^Windows^\\^',
    'sec-fetch-site': 'same-origin',
    'sec-fetch-mode': 'cors',
    'sec-fetch-dest': 'empty',
    'referer': 'https://www.autolist.com/listings',
    'accept-language': 'en-US,en;q=0.9',
    'cookie': 'ec=eyJlZGdlVXNlckFnZW50IjoiTW96aWxsYS81LjAgKFdpbmRvd3MgTlQgMTAuMDsgV2luNjQ7IHg2NCkgQXBwbGVXZWJLaXQvNTM3LjM2IChLSFRNTCwgbGlrZSBHZWNrbykgQ2hyb21lLzk0LjAuNDU5MC4wIFNhZmFyaS81MzcuMzYifQ==; client_guid_timestamp=1602952f-d1bf-4936-82e3-cbdedfa11d2d.1627825394925; scavenger-a493=...; _sp_ses.8ca5=*; _gid=GA1.2.96049973.1627825395; _fbp=fb.1.1627825395573.409117512; __gads=ID=c459f8bf6d0987dd:T=1627825394:S=ALNI_MaW1epD3HNJsvJQTCnPWSJCcOdE_w; AMP_TOKEN=^%^24NOT_FOUND; sp-nuid=e4461948-a1a2-45a1-88f8-45c2889d9576; _gcl_au=1.1.519751617.1627825557; _ga_152345333=GS1.1.1627825395.1.1.1627828426.0; _ga=GA1.2.2118379867.1627825395; cto_bundle=WV1etl8zMUc1cGt6WnZNSEZMYWhwNnJjUXpTYzQxVzZ6QzM5VE1tWXZFcjQ3ZWhrNTlETG1CemlUdmNFYUtIbXdCQTNFelJmY3h6QXA0SlVIZml0WVg2OWQxZlBPMmRqbExXNU9XZTM0V0VaR09tbHBvJTJGdERCb21zZUVKJTJCTG1vVzlDV0w2VjA0bDklMkJnRjdrMmZPUExmJTJGY0l6USUzRCUzRA; _gat=1; _sp_id.8ca5=d3d3f60d-371c-4289-92fe-1c6f66b4979f.1627825395.1.1627828912.1627825395.8bc1e545-8ca1-448e-b1ba-ec8d2c359ada',
    'if-none-match': 'W/^\\^c6f72fa4ef059e03ea0309ebd57c197d^\\^',
}
model = []
mileage = []
year = []
dealer_name = []
price = []

for i in range(1,6):
    params = (
        ('make', 'Tesla'),
        ('location', 'San^%^20Francisco,^%^20CA'),
        ('latitude', '37.7749295'),
        ('longitude', '-122.4194155'),
        ('radius', '50'),
        ('page', str(i)),
    )
     
    response = requests.get('https://www.autolist.com/api/cwv/seo/listings', headers=headers, params=params)
    
    result_json = response.json()
    
    result_item = response.json()['search_results']
    
    for result in result_item:
    
        model.append(result['model'])
        mileage.append(result['mileage'])
        year.append(result['year'])
        dealer_name.append(result['dealer_name'])
        price.append(result['price'])

# %%
tesla_multiple_df = pd.DataFrame({'Model': model,'Mileage': mileage,'Year':year,'Dealer_name':dealer_name,
                        'Price':price})

# %%
tesla_multipal_df
# Out:
#       Model       Mileage  Year                              Dealer_name  \
# 0   Model 3  35,226 Miles  2018  Shift SF - Test Drives Delivered To You
# 1   Model 3  10,640 Miles  2020  Shift SF - Test Drives Delivered To You
# 2   Model 3  53,129 Miles  2018  Shift SF - Test Drives Delivered To You
# 3   Model 3  41,210 Miles  2019             CarMax Serramonte - Now Open
# 4   Model 3  28,890 Miles  2019  Shift SF - Test Drives Delivered To You
# ..      ...           ...   ...                                      ...
# 95  Model 3  40,319 Miles  2020           Mercedes-Benz Of Stevens Creek
# 96  Model 3  36,325 Miles  2019                    One Toyota Of Oakland
# 97  Model 3  54,647 Miles  2019                      San Jose Mitsubishi
# 98  Model X  48,877 Miles  2016                   North State Auto Sales
# 99  Model Y  49,869 Miles  2020                       Hayward Mitsubishi
#
#       Price
# 0   $45,950
# 1   $52,850
# 2   $43,950
# 3   $42,998
# 4   $49,950
# ..      ...
# 95  $49,390
# 96  $49,564
# 97  $40,999
# 98  $79,900
# 99  $60,999
#
# [100 rows x 5 columns]

# %% [markdown]
# #### Step 10 - Store Results in Excel

# %%
tesla_multipal_df.to_excel('tesla_multiple_page.xlsx', index = False )
